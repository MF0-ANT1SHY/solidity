# %%
# commit id: 2c1d065e549d549b3d586ebf8d654871ed99a02d
@ this stage, I want to figure out the programmtic approach to enable/disable all passes for solc.
enable/disable means:
if enable, keep no changes;
if disable, disable existing all passes.

I set a flag in Suite.cpp, to skip the run of suite.run() func.

# build the solc
mkdir -p build && cd build && cmake .. && make -j$(nproc)
